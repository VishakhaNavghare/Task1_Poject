# %%
from ast import And
#Check whether a student passed or failed

Totel_Marks=int(input("Enter the Total Marks:"))
if(Totel_Marks<=100):
   if(Totel_Marks>=45):
     print("Passed")
   else:
    print("Failed")
else:
  print("Invalid Marks")
# Out:
# Enter the Total Marks:254
# Invalid Marks
