# %%
# Find greater number between two numbers.

num1=int(input("Enter the Number1: "))
num2=int(input("Enter the Number2: "))

if(num1>num2):
  print("Greater Number: {num1}".format(num1=num1))
elif(num1<num2):
  print("Greater Number: {num2}".format(num2=num2))
else:
  print("Both the numbers are same")
# Out:
# Enter the Number1: 174
# Enter the Number2: 548
# Greater Number: 548
